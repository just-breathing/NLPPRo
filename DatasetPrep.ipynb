# %%
import pandas as pd

# %%
data1=pd.read_csv("dailydialog.csv")
data2=pd.read_csv("emotion-stimulus.csv")
data3=pd.read_csv("isear.csv")

# %%
data1[1:5]
# Out:
#    Emotion                                               Text
# 1        0   You know that is tempting but is really not g...
# 2        0     What do you mean ? It will help us to relax .
# 3        0   Do you really think so ? I don't . It will ju...
# 4        0   I guess you are right.But what shall we do ? ...

# %%
data2[1:5]
# Out:
#   Emotion                                               Text
# 1   happy  Lennox has always truly wanted to fight for th...
# 2   happy  He was a professional musician now , still sen...
# 3   happy  Holmes is happy having the freedom of the hous...
# 4   happy  I had problems with tutors trying to encourage...

# %%
data3[1:5]
# Out:
#    Emotion                                               Text
# 1     fear         When I was involved in a traffic accident.
# 2    anger  When I was driving home after  several days of...
# 3  sadness  When I lost the person who meant the most to me.
# 4  disgust  The time I knocked a deer down - the sight of ...

# %%
decode={0:"neutral", 1:"joy", 2:"surprise", 3:"sadness", 4:"anger", 5:"disgust",6: "fear"}

# %%
data1['Emotion'] = data1['Emotion'].replace(decode)

# %%
data1['Emotion'].value_counts()
# Out:
# neutral     85572
# anger       12885
# fear         1823
# disgust      1150
# joy          1022
# surprise      353
# sadness       174
# Name: Emotion, dtype: int64

# %%
data2['Emotion'].value_counts()
# Out:
# sad         575
# anger       483
# happy       479
# fear        423
# surprise    213
# shame       146
# disgust      95
# Name: Emotion, dtype: int64

# %%
data2.loc[data2["Emotion"] == "sad", "Emotion"] = "sadness"

# %%
data2['Emotion'].value_counts()
# Out:
# sadness     575
# anger       483
# happy       479
# fear        423
# surprise    213
# shame       146
# disgust      95
# Name: Emotion, dtype: int64

# %%
data3['Emotion'].value_counts()
# Out:
# joy        1081
# fear       1081
# anger      1071
# sadness    1067
# disgust    1067
# shame      1054
# guilt      1052
# Name: Emotion, dtype: int64

# %%
# Filter and select columns of interest for each dataset
filter=['joy', 'sadness', 'anger', 'fear', 'neutral']
data1_filtered = data1[data1['Emotion'].isin(filter)]
data2_filtered = data2[data2['Emotion'].isin(filter)]
data3_filtered = data3[data3['Emotion'].isin(filter)]

# Combine the filtered datasets into a single DataFrame
combined_data = pd.concat([data1_filtered, data2_filtered, data3_filtered])

# Resetting the index of the combined DataFrame
combined_data.reset_index(drop=True, inplace=True)

# %%
combined_data.Emotion.count()
# Out:
# 107257

# %%
combined_data['Emotion'].value_counts()
# Out:
# neutral    85572
# anger      14439
# fear        3327
# joy         2103
# sadness     1816
# Name: Emotion, dtype: int64

# %%
combined_data[1:5]
# Out:
#    Emotion                                               Text  sad
# 1  neutral   You know that is tempting but is really not g...  NaN
# 2  neutral     What do you mean ? It will help us to relax .   NaN
# 3  neutral   Do you really think so ? I don't . It will ju...  NaN
# 4  neutral   I guess you are right.But what shall we do ? ...  NaN

# %%
trainData=pd.read_csv("data_train.csv")
testData=pd.read_csv("data_test.csv")

# %%
trainData[1:5]
# Out:
#    Emotion                                               Text
# 1  sadness  Yet the dog had grown old and less capable , a...
# 2     fear  When I get into the tube or the train without ...
# 3     fear  This last may be a source of considerable disq...
# 4    anger  She disliked the intimacy he showed towards so...

# %%
len(trainData)
# Out:
# 7934

# %%
emotion_counts = combined_data['Emotion'].value_counts()

# %%
len(testData)
# Out:
# 3393

# %%
class_counts = {'neutral': 3393, 'anger': 3393, 'fear': 3327, 'joy': 2103, 'sadness': 1816}

undersample = RandomUnderSampler(sampling_strategy=class_counts, random_state=42)
X, y = combined_data.drop('Emotion', axis=1), combined_data['Emotion']
X_resampled, y_resampled = undersample.fit_resample(X, y)

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=3393,train_size=7934, random_state=42)

# %%
trainData = pd.concat([X_train, pd.DataFrame({'Emotion': y_train})], axis=1)
trainData.to_csv('data_train.csv', index=False)

# %%
testData = pd.concat([X_test, pd.DataFrame({'Emotion': y_test})], axis=1)
testData.to_csv('data_test.csv', index=False)
